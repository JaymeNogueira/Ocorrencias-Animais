# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

dc = pd.read_csv('dadoscorrigidos.csv')
tbanimal = pd.read_csv('animal.csv')

# %%
dc.head(10)
# Out:
#    FaixaKm  codAnimal  TipoPavimento  TipoChuva  Intervencao  Vazamento  agua  \
# 0        5        334              2          1            0          0     0
# 1        5          1              2          1            0          0     0
# 2        5         18              4          1            1          0     1
# 3        5        361              4          1            1          0     0
# 4        4         48              4          1            0          0     1
# 5        2        329              4          1            0          0     1
# 6        2        286              4          1            1          1     1
# 7        4        362              4          1            0          0     0
# 8        5        363              2          1            0          0     0
# 9        4        364              4          1            1          0     0
#
#    vegetacaoBaixa  capimAlto  arbustos  floresta  TipoLocal  Taxonomia  Ave  \
# ...

# %%
mamdc = dc.drop(['Taxonomia','codAnimal', 'Ave', 'Reptil', 'Anfibio'], axis=1)
mamdc.head()
# Out:
#    FaixaKm  TipoPavimento  TipoChuva  Intervencao  Vazamento  agua  \
# 0        5              2          1            0          0     0
# 1        5              2          1            0          0     0
# 2        5              4          1            1          0     1
# 3        5              4          1            1          0     0
# 4        4              4          1            0          0     1
#
#    vegetacaoBaixa  capimAlto  arbustos  floresta  TipoLocal  Mamifero
# 0               0          0         0         1          5         0
# 1               0          0         0         1          6         0
# 2               0          0         0         1          6         0
# 3               0          0         0         1          5         0
# 4               0          0         0         1          5         0

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(mamdc.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)

# %%
mamasc = mamdc
headers = ['FaixaKm','TipoPavimento','TipoChuva','Intervencao',
           'Vazamento','agua','vegetacaoBaixa','capimAlto','arbustos','floresta','TipoLocal','Mamifero']
for i in range(len(headers)):
    mamasc[headers[i]] = headers[i]+'='+mamasc[headers[i]].apply(str)

mamasc.head()
# Out:
#      FaixaKm    TipoPavimento    TipoChuva    Intervencao    Vazamento  \
# 0  FaixaKm=5  TipoPavimento=2  TipoChuva=1  Intervencao=0  Vazamento=0
# 1  FaixaKm=5  TipoPavimento=2  TipoChuva=1  Intervencao=0  Vazamento=0
# 2  FaixaKm=5  TipoPavimento=4  TipoChuva=1  Intervencao=1  Vazamento=0
# 3  FaixaKm=5  TipoPavimento=4  TipoChuva=1  Intervencao=1  Vazamento=0
# 4  FaixaKm=4  TipoPavimento=4  TipoChuva=1  Intervencao=0  Vazamento=0
#
#      agua    vegetacaoBaixa    capimAlto    arbustos    floresta    TipoLocal  \
# 0  agua=0  vegetacaoBaixa=0  capimAlto=0  arbustos=0  floresta=1  TipoLocal=5
# 1  agua=0  vegetacaoBaixa=0  capimAlto=0  arbustos=0  floresta=1  TipoLocal=6
# 2  agua=1  vegetacaoBaixa=0  capimAlto=0  arbustos=0  floresta=1  TipoLocal=6
# 3  agua=0  vegetacaoBaixa=0  capimAlto=0  arbustos=0  floresta=1  TipoLocal=5
# 4  agua=1  vegetacaoBaixa=0  capimAlto=0  arbustos=0  floresta=1  TipoLocal=5
#
#      Mamifero
# 0  Mamifero=0
# 1  Mamifero=0
# 2  Mamifero=0
# ...

# %%
listmamasc = []
for i in range(len(mamasc)):
    listmamasc.append([str(mamasc.values[i, j]) for j in range(0, 12)])

from apyori import apriori
regras = apriori(listmamasc, min_support=0.03, min_confidence=0.8, min_lenght=2)

resultados = list(regras)
resultados2 = [list(x) for x in resultados]
resultadosFormatado = []
for j in range(0,1000):#numero de regras que deseja mostrar
       resultadosFormatado.append([list(x) for x in resultados2[j][2]])
resultdf = pd.DataFrame(resultadosFormatado)
resultdf.to_csv('mamregras.csv', index=False, header=False)

# %% [markdown]
# |SE|E|ENTÃO|SUPORTE|LIFT|
# |:---|:---|:---|:---|
# |Mamifero=1|FaixaKm=1|Intervencao=0|0.9169435215946843|1.1169250141980762|
# |Mamifero=1|FaixaKm=1|TipoChuva=1|0.9734219269102989|1.0175232171468223|
# |Mamifero=1|FaixaKm=1|TipoPavimento=4|0.9900332225913621|1.1884306229563695|
# |Mamifero=1|FaixaKm=1|floresta=0|0.9568106312292358|1.6918657329690319|
# |Mamifero=1|FaixaKm=2|Intervencao=0|0.9029850746268656|1.0999222891549896|
# |Mamifero=1|FaixaKm=2|TipoChuva=1|0.9701492537313433|1.0141022741316073|
# |Mamifero=1|FaixaKm=2|TipoPavimento=4|0.9850746268656716|1.1824783509792265|
# |Mamifero=1|FaixaKm=2|floresta=0|0.8283582089552238|1.4647317061626326|
# |Mamifero=1|FaixaKm=3|Intervencao=0|0.9315589353612167|1.1347279877119791|
# |Mamifero=1|FaixaKm=3|TipoChuva=1|0.9619771863117871|1.0055599677569391|
# |Mamifero=1|FaixaKm=3|TipoPavimento=4|0.9771863117870722|1.173009259448744|
# |Mamifero=1|FaixaKm=4|Intervencao=0|0.8832116788321168|1.0758363996114497|
# |Mamifero=1|FaixaKm=4|TipoChuva=1|0.927007299270073|0.9690057552594997|
# |Mamifero=1|FaixaKm=4|TipoPavimento=4|0.9464720194647203|1.1361399860492363|
# |Mamifero=1|FaixaKm=4|agua=0|0.8077858880778589|1.1388317271658142|
# |Mamifero=1|FaixaKm=4|capimAlto=0|0.8856447688564477|1.0905132772209223|
# |FaixaKm=5|Mamifero=1|TipoChuva=1|0.9299111549851925|0.9720411713803973|
# |Mamifero=1|TipoPavimento=2|FaixaKm=5|0.8660049627791563|3.1355190508416313|
# |FaixaKm=5|Mamifero=1|agua=0|0.8647581441263573|1.219152284523695|
# |FaixaKm=5|Mamifero=1|capimAlto=0|0.8904244817374136|1.0963986395482213|
# |Mamifero=1|FaixaKm=9|Intervencao=0|0.9691629955947135|1.1805333339749187|
# |Mamifero=1|FaixaKm=9|TipoChuva=1|0.933920704845815|0.9762323755855878|
# |Mamifero=1|FaixaKm=9|TipoPavimento=4|0.9779735682819384|1.1739542779645586|
# |Mamifero=1|FaixaKm=9|capimAlto=0|0.8898678414096916|1.0957132364505422|
# |Intervencao=0|Mamifero=1|TipoChuva=1|0.9470026064291919|0.989906958228046|
# |Intervencao=0|Mamifero=1|TipoPavimento=4|0.8436142484795829|1.0126700639714548]|
# |TipoPavimento=4|Mamifero=1|Intervencao=0|0.8274392841925862|1.0079002822742753]|
# |Mamifero=1|Vazamento=0|Intervencao=0|0.8210810810810811|1.000155382034137|
# |Mamifero=1|agua=1|Intervencao=0|0.828804347826087|1.0095630604959673|
# |Mamifero=1|arbustos=0|Intervencao=0|0.8095238095238095|0.9860775185734225|
# |Intervencao=0|Mamifero=1|capimAlto=0|0.8266724587315377|1.0178994150483471|
# |floresta=0|Mamifero=1|Intervencao=0|0.8316546762589927|1.0130350334696743|
# |Intervencao=1|Mamifero=1|TipoChuva=1|0.9428571428571428|0.9855736826835092|
# |Intervencao=1|Mamifero=1|agua=0|0.8|1.1278550358196378|
# |Mamifero=1|TipoLocal=5|TipoChuva=1|0.9455128205128205|0.9883496769334918|
# |TipoLocal=6|Mamifero=1|TipoChuva=1|0.9447470817120622|0.9875492460139679|
# |Mamifero=1|TipoPavimento=2|TipoChuva=1|0.9330024813895781|0.9752725516290683|
# |TipoChuva=1|Mamifero=1|TipoPavimento=4|0.8028118240807498|0.9636910503990486]|
# |TipoPavimento=4|Mamifero=1|TipoChuva=1|0.9488708990200254|0.9918598946013106]|
# |Mamifero=1|Vazamento=0|TipoChuva=1|0.9481081081081082|0.9910625451259727|
# |Mamifero=1|Vazamento=1|TipoChuva=1|0.9426987060998152|0.9854080678821845|
# |agua=0|Mamifero=1|TipoChuva=1|0.9521857923497267|0.9953249705689768|
# |Mamifero=1|agua=1|TipoChuva=1|0.9279891304347826|0.9700320686985049|
# |Mamifero=1|arbustos=0|TipoChuva=1|0.9470899470899472|0.9899982558942098|
# |arbustos=1|Mamifero=1|TipoChuva=1|0.944337811900192|0.9871214340609568|
# |TipoChuva=1|Mamifero=1|capimAlto=0|0.8183129055515501|1.0076061190735042|
# |Mamifero=1|capimAlto=0|TipoChuva=1|0.9450457951706911|0.9878614928116066|
# |Mamifero=1|capimAlto=1|TipoChuva=1|0.9509433962264151|0.9940262871662151|
# |floresta=0|Mamifero=1|TipoChuva=1|0.953956834532374|0.9971762505633673|
# |Mamifero=1|floresta=1|TipoChuva=1|0.9390402075226978|0.9815838194867006|
# |Mamifero=1|vegetacaoBaixa=0|TipoChuva=1|0.9422969187675071|0.9849880774056226|
# |Mamifero=1|vegetacaoBaixa=1|TipoChuva=1|0.952048823016565|0.9951817957825084|
# |Mamifero=1|TipoLocal=5|TipoPavimento=4|0.8865384615384615|1.0641960613838977|
# |TipoLocal=6|Mamifero=1|capimAlto=0|0.8630350194552528|1.0626734109633964|
# |Mamifero=1|TipoPavimento=2|agua=0|0.8709677419354839|1.2279066922229926|
# |Mamifero=1|TipoPavimento=2|capimAlto=0|0.9478908188585607|1.1671581650685736|
# |Mamifero=1|TipoPavimento=2|floresta=1|0.8808933002481388|2.0275394124390425|
# |Mamifero=1|Vazamento=0|TipoPavimento=4|0.8702702702702703|1.0446678109756689|
# |Mamifero=1|agua=1|TipoPavimento=4|0.9008152173913043|1.0813338032948003|
# |Mamifero=1|arbustos=0|TipoPavimento=4|0.8222222222222223|0.9869911892516845|
# |Mamifero=1|capimAlto=1|TipoPavimento=4|0.9509433962264151|1.1415074029693117|
# |floresta=0|Mamifero=1|TipoPavimento=4|0.9359712230215826|1.1235348857620038|
# |Mamifero=1|vegetacaoBaixa=1|TipoPavimento=4|0.865736704446382|1.0392257426355833|
# |Mamifero=1|Vazamento=1|capimAlto=0|0.8613678373382624|1.0606205740946473|
# |agua=0|Mamifero=1|capimAlto=0|0.837431693989071|1.0311474907031422|
# |Mamifero=1|floresta=1|agua=0|0.8184176394293126|1.1538205700424633|
# |arbustos=1|Mamifero=1|capimAlto=0|0.8685220729366603|1.0694297368456374|
# |Mamifero=1|floresta=1|capimAlto=0|0.913099870298314|1.1243193287018804|
# |Mamifero=1|vegetacaoBaixa=1|capimAlto=0|0.8570183086312119|1.0552649067080306|
# |Mamifero=1|floresta=1|vegetacaoBaixa=0|0.8073929961089494|1.5094346289368485|
# |Intervencao=0 Mamifero=1|FaixaKm=1|TipoChuva=1|0.9710144927536233|1.0150067131720815|
# |TipoChuva=1 Mamifero=1|FaixaKm=1|Intervencao=0|0.9146757679180888|1.1141626730638872|
# |TipoLocal=5 Mamifero=1|FaixaKm=1|Intervencao=0|0.9039301310043668|1.1010734583197193|
# |Intervencao=0 Mamifero=1|FaixaKm=1|TipoPavimento=4|0.9891304347826089|1.187346921264879|
# |TipoPavimento=4 Mamifero=1|FaixaKm=1|Intervencao=0|0.9161073825503356|1.115906516774858|
# |capimAlto=0 Mamifero=1|FaixaKm=1|Intervencao=0|0.9403669724770642|1.1454570203611938|
# |Intervencao=0 Mamifero=1|FaixaKm=1|floresta=0|0.9528985507246378|1.6849482565799554|
# |floresta=0 Mamifero=1|FaixaKm=1|Intervencao=0|0.9131944444444444|1.112358279224063|

# %% [markdown]
# # Ocorrencia com Mamifero mais atropelado

# %%
mamdc = dc.drop(['Taxonomia', 'Ave', 'Reptil', 'Anfibio'], axis=1)
mamdc = mamdc[mamdc.Mamifero == 1]
mamdc.head()
# Out:
#     FaixaKm  codAnimal  TipoPavimento  TipoChuva  Intervencao  Vazamento  \
# 8         5        363              2          1            0          0
# 9         4        364              4          1            1          0
# 10        6        364              1          1            1          0
# 11        6        363              4          1            1          0
# 12        5        364              4          1            0          0
#
#     agua  vegetacaoBaixa  capimAlto  arbustos  floresta  TipoLocal  Mamifero
# 8      0               0          0         0         1          6         1
# 9      0               0          0         0         1          6         1
# 10     0               0          0         0         1          6         1
# 11     0               0          0         0         1          5         1
# 12     0               0          0         0         1          5         1

# %%
mamdc.groupby('codAnimal').size().sort_values(ascending=False).head(3)
# Out:
# codAnimal
# 363    806
# 222    237
# 188    137
# dtype: int64

# %%
tbanimal[tbanimal.codAnimal == 363]
# Out:
#      codAnimal              nomeComum    nomeCientifico  codGrupoTax  \
# 331        363  gambá-de-orelha-preta  Didelphis aurita            4
#
#      codValorBiologico
# 331                  7

# %%
mamdc['Gamba'] = (mamdc['codAnimal'] == 363)*1
mamdc.head()
# Out:
#     FaixaKm  codAnimal  TipoPavimento  TipoChuva  Intervencao  Vazamento  \
# 8         5        363              2          1            0          0
# 9         4        364              4          1            1          0
# 10        6        364              1          1            1          0
# 11        6        363              4          1            1          0
# 12        5        364              4          1            0          0
#
#     agua  vegetacaoBaixa  capimAlto  arbustos  floresta  TipoLocal  Mamifero  \
# 8      0               0          0         0         1          6         1
# 9      0               0          0         0         1          6         1
# 10     0               0          0         0         1          6         1
# 11     0               0          0         0         1          5         1
# 12     0               0          0         0         1          5         1
#
#     Gamba
# 8       1
# 9       0
# 10      0
# 11      1
# ...

# %%
gambadc = mamdc.drop(['codAnimal', 'Mamifero'], axis=1)
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(gambadc.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)

# %%
headers = ['FaixaKm','TipoPavimento','TipoChuva','Intervencao',
           'Vazamento','agua','vegetacaoBaixa','capimAlto','arbustos','floresta','TipoLocal','Gamba']
for i in range(len(headers)):
    gambadc[headers[i]] = headers[i]+'='+gambadc[headers[i]].apply(str)

gambadc.head()
# Out:
#       FaixaKm    TipoPavimento    TipoChuva    Intervencao    Vazamento  \
# 8   FaixaKm=5  TipoPavimento=2  TipoChuva=1  Intervencao=0  Vazamento=0
# 9   FaixaKm=4  TipoPavimento=4  TipoChuva=1  Intervencao=1  Vazamento=0
# 10  FaixaKm=6  TipoPavimento=1  TipoChuva=1  Intervencao=1  Vazamento=0
# 11  FaixaKm=6  TipoPavimento=4  TipoChuva=1  Intervencao=1  Vazamento=0
# 12  FaixaKm=5  TipoPavimento=4  TipoChuva=1  Intervencao=0  Vazamento=0
#
#       agua    vegetacaoBaixa    capimAlto    arbustos    floresta  \
# 8   agua=0  vegetacaoBaixa=0  capimAlto=0  arbustos=0  floresta=1
# 9   agua=0  vegetacaoBaixa=0  capimAlto=0  arbustos=0  floresta=1
# 10  agua=0  vegetacaoBaixa=0  capimAlto=0  arbustos=0  floresta=1
# 11  agua=0  vegetacaoBaixa=0  capimAlto=0  arbustos=0  floresta=1
# 12  agua=0  vegetacaoBaixa=0  capimAlto=0  arbustos=0  floresta=1
#
#       TipoLocal    Gamba
# 8   TipoLocal=6  Gamba=1
# 9   TipoLocal=6  Gamba=0
# 10  TipoLocal=6  Gamba=0
# 11  TipoLocal=5  Gamba=1
# ...

# %%
listgamba = []
for i in range(len(gambadc)):
    listgamba.append([str(gambadc.values[i, j]) for j in range(0, 12)])

from apyori import apriori
regras = apriori(listgamba, min_support=0.03, min_confidence=0.8, min_lenght=2)

resultados = list(regras)
resultados2 = [list(x) for x in resultados]
resultadosFormatado = []
for j in range(0,3000):#numero de regras que deseja mostrar
       resultadosFormatado.append([list(x) for x in resultados2[j][2]])
resultdf = pd.DataFrame(resultadosFormatado)
resultdf.to_csv('gambaregras.csv', index=False, header=False)

# %% [markdown]
# |SE|E|E|ENTÃO|SUPORTE|LIFT|
# |:---|:---|:---|:---|:---|
# |Gamba=1|FaixaKm=4||Intervencao=0|0.9248120300751881|1.177910022667442|
# |Gamba=1|FaixaKm=4||TipoChuva=1|0.9097744360902256|0.9615928790975276|
# |Gamba=1|FaixaKm=4||TipoPavimento=4|0.9473684210526316|1.1835041374206714|
# |Gamba=1|FaixaKm=4||agua=0|0.9323308270676692|1.2448060040812414|
# |Gamba=1|FaixaKm=4||arbustos=0|0.8045112781954888|1.248056649560409|
# |Gamba=1|FaixaKm=4||capimAlto=0|0.9398496240601505|1.147226934947694|
# |Gamba=1|FaixaKm=4||floresta=1|0.8496240601503761|1.6154978886905982|
# |Gamba=1|FaixaKm=4||vegetacaoBaixa=0|0.887218045112782|1.4573239822244688|
# |FaixaKm=5|Gamba=1||TipoChuva=1|0.9137055837563451|0.9657479349580403|
# |TipoPavimento=2|Gamba=1||FaixaKm=5|0.9047619047619048|2.6187185634372208|
# |FaixaKm=5|Gamba=1||agua=0|0.8527918781725888|1.1386091925328008|
# |FaixaKm=5|Gamba=1||capimAlto=0|0.9111675126903553|1.1122161312273613|
# |Intervencao=0|Gamba=1||TipoChuva=1|0.9329073482428115|0.9860433832184294|
# |TipoPavimento=4|Gamba=1||Intervencao=0|0.8447971781305115|1.0759971009029798|
# |Gamba=1|Vazamento=0||Intervencao=0|0.8389662027833003|1.06857033299767|
# |Gamba=1|agua=1||Intervencao=0|0.8148148148148149|1.0378093123531873|
# |Intervencao=0|Gamba=1||capimAlto=0|0.8578274760383388|1.04710664435654|
# |floresta=0|Gamba=1||Intervencao=0|0.842948717948718|1.073642763260487|
# |Intervencao=1|Gamba=1||TipoChuva=1|0.9222222222222223|0.9747496595369703|
# |Intervencao=1|Gamba=1||agua=0|0.8333333333333334|1.112629022465088|
# |Intervencao=1|Gamba=1||capimAlto=0|0.8666666666666667|1.0578961976131003|
# |Gamba=1|TipoLocal=5||TipoChuva=1|0.9251968503937008|0.9778937149799318|
# |TipoLocal=6|Gamba=1||TipoChuva=1|0.9334600760456274|0.9866275929941527|
# |TipoPavimento=2|Gamba=1||TipoChuva=1|0.9226190476190476|0.9751690871013149|
# |TipoPavimento=4|Gamba=1||TipoChuva=1|0.9365079365079365|0.9898490518533778|
# |Gamba=1|Vazamento=0||TipoChuva=1|0.9343936381709742|0.9876143284489173|
# |Vazamento=1|Gamba=1||TipoChuva=1|0.9240924092409241|0.9767263676620005|
# |TipoChuva=1|Gamba=1||agua=0|0.8133333333333335|1.085925925925926|
# |agua=0|Gamba=1||TipoChuva=1|0.9472049689440994|1.001155360109625|
# |Gamba=1|agua=1||TipoChuva=1|0.8641975308641975|0.9134200290172412|
# |Gamba=1|arbustos=0||TipoChuva=1|0.9356223175965666|0.9889129903363855|
# |arbustos=1|Gamba=1||TipoChuva=1|0.9235294117647059|0.976131303278341|
# |TipoChuva=1|Gamba=1||capimAlto=0|0.86|1.049758534554538|
# |capimAlto=0|Gamba=1||TipoChuva=1|0.9307359307359307|0.9837482872810919|
# |Gamba=1|capimAlto=1||TipoChuva=1|0.9292035398230087|0.9821286152707505|
# |floresta=0|Gamba=1||TipoChuva=1|0.9391025641025642|0.992591462851016|
# |floresta=1|Gamba=1||TipoChuva=1|0.9251012145748988|0.9777926319876004|
# |vegetacaoBaixa=0|Gamba=1||TipoChuva=1|0.927304964539007|0.980121901956874|
# |vegetacaoBaixa=1|Gamba=1||TipoChuva=1|0.9380165289256198|0.9914435698665888|
# |Gamba=1|TipoLocal=5||capimAlto=0|0.8267716535433071|1.0091983714358768|
# |TipoLocal=6|Gamba=1||agua=0|0.8060836501901141|1.07624647648334|
# |TipoLocal=6|Gamba=1||capimAlto=0|0.8745247148288974|1.0674881198494284|
# |TipoPavimento=2|Gamba=1||agua=0|0.8452380952380952|1.1285237227860179|
# |TipoPavimento=2|Gamba=1||capimAlto=0|0.9523809523809524|1.1625232940803298|
# |TipoPavimento=2|Gamba=1||floresta=1|0.9226190476190476|1.7542925081835585|
# |Gamba=1|Vazamento=0||TipoPavimento=4|0.8151093439363818|1.0182789077211212|
# |TipoPavimento=4|Gamba=1||capimAlto=0|0.8148148148148148|0.994603262713171|
# |Gamba=1|capimAlto=1||TipoPavimento=4|0.9292035398230087|1.1608115802134902|
# |floresta=0|Gamba=1||TipoPavimento=4|0.9134615384615384|1.141145816262987|
# |Gamba=1|Vazamento=0||capimAlto=0|0.8330019880715707|1.0168034259058472|
# |Vazamento=1|Gamba=1||agua=0|0.8547854785478548|1.1412709576968625|
# |Vazamento=1|Gamba=1||capimAlto=0|0.9042904290429042|1.1038216227950854|
# |Gamba=1|arbustos=0||agua=0|0.8133047210300429|1.0858877240710774|
# |agua=0|Gamba=1||capimAlto=0|0.8664596273291926|1.0576434751578654|
# |capimAlto=0|Gamba=1||agua=0|0.8051948051948052|1.0750597307974357|
# |floresta=1|Gamba=1||agua=0|0.8421052631578948|1.124340906912089|
# |vegetacaoBaixa=0|Gamba=1||agua=0|0.8102836879432623|1.081854177162862|
# |Gamba=1|agua=1||capimAlto=0|0.8333333333333334|1.0172078823202886|
# |Gamba=1|arbustos=0||capimAlto=0|0.8347639484978542|1.0189541619465896|
# |arbustos=1|Gamba=1||capimAlto=0|0.8941176470588236|1.0914042219718862|
# |floresta=1|Gamba=1||capimAlto=0|0.9534412955465587|1.1638176013915529|
# |vegetacaoBaixa=0|Gamba=1||capimAlto=0|0.8634751773049645|1.0540005078510224|
# |vegetacaoBaixa=1|Gamba=1||capimAlto=0|0.8512396694214877|1.0390652417751047|
# |floresta=1|Gamba=1||vegetacaoBaixa=0|0.8360323886639677|1.3732475986345958|
# |Intervencao=0|Gamba=1|FaixaKm=4|TipoChuva=1|0.9268292682926828|0.9796191112596055|
# |TipoChuva=1|Gamba=1|FaixaKm=4|Intervencao=0|0.9421487603305785|1.1999913837051503|
# |Intervencao=0|Gamba=1|FaixaKm=4|TipoPavimento=4|0.9430894308943089|1.1781585902778497|
# |TipoPavimento=4|Gamba=1|FaixaKm=4|Intervencao=0|0.9206349206349206|1.1725897425289258|
# |Intervencao=0|Gamba=1|FaixaKm=4|agua=0|0.9268292682926828|1.2374605713270244|
# |agua=0|Gamba=1|FaixaKm=4|Intervencao=0|0.9193548387096774|1.1709593340993805|
# |Intervencao=0|Gamba=1|FaixaKm=4|arbustos=0|0.8130081300813008|1.261238009205489|
# |arbustos=0|Gamba=1|FaixaKm=4|Intervencao=0|0.9345794392523364|1.190350528187598|
# |Intervencao=0|Gamba=1|FaixaKm=4|capimAlto=0|0.9593495934959348|1.1710295620857956|
# |capimAlto=0|Gamba=1|FaixaKm=4|Intervencao=0|0.944|1.2023492615117288|
# |Intervencao=0|Gamba=1|FaixaKm=4|floresta=1|0.8536585365853657|1.6231691499794372|
# |floresta=1|Gamba=1|FaixaKm=4|Intervencao=0|0.9292035398230087|1.1835033791316514|
# |Intervencao=0|Gamba=1|FaixaKm=4|vegetacaoBaixa=0|0.9186991869918699|1.5090341827788025|
# |vegetacaoBaixa=0|Gamba=1|FaixaKm=4|Intervencao=0|0.9576271186440679|1.219705782738665|
# |TipoChuva=1|Gamba=1|FaixaKm=4|TipoPavimento=4|0.9504132231404959|1.1873078697264312|
# |TipoPavimento=4|Gamba=1|FaixaKm=4|TipoChuva=1|0.9126984126984126|0.9646833979926985|
# |TipoChuva=1|Gamba=1|FaixaKm=4|agua=0|0.9256198347107438|1.2358457902422135|
# |agua=0|Gamba=1|FaixaKm=4|TipoChuva=1|0.9032258064516129|0.9546712561341488|
# |TipoChuva=1|Gamba=1|FaixaKm=4|arbustos=0|0.8016528925619835|1.2436223708950982|
# |arbustos=0|Gamba=1|FaixaKm=4|TipoChuva=1|0.9065420560747663|0.9581763909196882|
# |TipoChuva=1|Gamba=1|FaixaKm=4|capimAlto=0|0.9338842975206613|1.1399453623357947|
# |capimAlto=0|Gamba=1|FaixaKm=4|TipoChuva=1|0.904|0.9554895457822639|
# |TipoChuva=1|Gamba=1|FaixaKm=4|floresta=1|0.834710743801653|1.5871413105229872|
# |floresta=1|Gamba=1|FaixaKm=4|TipoChuva=1|0.8938053097345133|0.9447141918318649|
# |TipoChuva=1|Gamba=1|FaixaKm=4|vegetacaoBaixa=0|0.8842975206611571|1.452526795842304|
# |vegetacaoBaixa=0|Gamba=1|FaixaKm=4|TipoChuva=1|0.9067796610169492|0.9584275292363716|
# |TipoPavimento=4|Gamba=1|FaixaKm=4|agua=0|0.9285714285714284|1.2397866250325265|
# |agua=0|Gamba=1|FaixaKm=4|TipoPavimento=4|0.9435483870967741|1.1787319433181687|
# |TipoPavimento=4|Gamba=1|FaixaKm=4|arbustos=0|0.8253968253968254|1.2804568741076676|
# |arbustos=0|Gamba=1|FaixaKm=4|TipoPavimento=4|0.9719626168224299|1.2142285438957667|
# |TipoPavimento=4|Gamba=1|FaixaKm=4|capimAlto=0|0.9365079365079364|1.1431479058456575|
# |capimAlto=0|Gamba=1|FaixaKm=4|TipoPavimento=4|0.944|1.1792961227098422|
# |TipoPavimento=4|Gamba=1|FaixaKm=4|floresta=1|0.8412698412698412|1.5996129536985566|
# |floresta=1|Gamba=1|FaixaKm=4|TipoPavimento=4|0.9380530973451326|1.1718669285964758|
# |TipoPavimento=4|Gamba=1|FaixaKm=4|vegetacaoBaixa=0|0.8888888888888888|1.4600684718331778|
# |vegetacaoBaixa=0|Gamba=1|FaixaKm=4|TipoPavimento=4|0.9491525423728814|1.185732958771746|
# |agua=0|Gamba=1|FaixaKm=4|arbustos=0|0.8064516129032259|1.2510667349377027|
# |arbustos=0|Gamba=1|FaixaKm=4|agua=0|0.9345794392523364|1.2478082494935567|
# |agua=0|Gamba=1|FaixaKm=4|capimAlto=0|0.9435483870967741|1.1517418280465204|
# |capimAlto=0|Gamba=1|FaixaKm=4|agua=0|0.9359999999999999|1.2497049180327868|
# |agua=0|Gamba=1|FaixaKm=4|floresta=1|0.8709677419354839|1.6560813355089745|
# |floresta=1|Gamba=1|FaixaKm=4|agua=0|0.9557522123893805|1.2760771797475698|
# |agua=0|Gamba=1|FaixaKm=4|vegetacaoBaixa=0|0.8951612903225806|1.4703713743561941|
# |vegetacaoBaixa=0|Gamba=1|FaixaKm=4|agua=0|0.9406779661016949|1.255950727053811|
# |arbustos=0|Gamba=1|FaixaKm=4|capimAlto=0|0.9345794392523364|1.1407938867143423|
# |capimAlto=0|Gamba=1|FaixaKm=4|arbustos=0|0.8|1.2410582010582012|
# |arbustos=0|Gamba=1|FaixaKm=4|floresta=1|0.9158878504672897|1.7414936300713963|
# |floresta=1|Gamba=1|FaixaKm=4|arbustos=0|0.8672566371681416|1.3453949524745985|
# |arbustos=0|Gamba=1|FaixaKm=4|vegetacaoBaixa=0|0.9065420560747663|1.48906515877379|
# |vegetacaoBaixa=0|Gamba=1|FaixaKm=4|arbustos=0|0.8220338983050848|1.275239888799211|
# |capimAlto=0|Gamba=1|FaixaKm=4|floresta=1|0.896|1.7036783398184177|
# |floresta=1|Gamba=1|FaixaKm=4|capimAlto=0|0.9911504424778761|1.2098472511844849|
# |capimAlto=0|Gamba=1|FaixaKm=4|vegetacaoBaixa=0|0.904|1.4848896358543417|
# |vegetacaoBaixa=0|Gamba=1|FaixaKm=4|capimAlto=0|0.9576271186440679|1.1689270240900944|
# |floresta=1|Gamba=1|FaixaKm=4|vegetacaoBaixa=0|0.9380530973451326|1.540824471381473|
# |vegetacaoBaixa=0|Gamba=1|FaixaKm=4|floresta=1|0.8983050847457628|1.7080612895425267|
# |FaixaKm=5|Intervencao=0|Gamba=1|TipoChuva=1|0.8992248062015503|0.9504423690637871|
# |FaixaKm=5|Intervencao=0|Gamba=1|TipoLocal=6|0.8294573643410853|1.8925828733447954|
# |FaixaKm=5|Intervencao=0|Gamba=1|agua=0|0.8410852713178295|1.122979059883368|
# |FaixaKm=5|Intervencao=0|Gamba=1|capimAlto=0|0.9186046511627908|1.121294270278644|
# |FaixaKm=5|Intervencao=0|Gamba=1|vegetacaoBaixa=0|0.8255813953488371|1.356081037065989|
# |Intervencao=1|FaixaKm=5|Gamba=1|TipoChuva=1|0.9411764705882354|0.9947834937868444|
# |Intervencao=1|FaixaKm=5|Gamba=1|agua=0|0.8750000000000001|1.1682604735883426|
# |Intervencao=1|FaixaKm=5|Gamba=1|capimAlto=0|0.8970588235294118|1.0949943674388989|
# |Intervencao=1|floresta=1|Gamba=1|FaixaKm=5|0.816793893129771|2.3641063125927824|
# |Intervencao=1|vegetacaoBaixa=0|Gamba=1|FaixaKm=5|0.8053097345132744|2.3308668722536234|
# |FaixaKm=5|TipoLocal=6|Gamba=1|TipoChuva=1|0.9144736842105263|0.9665597844647669|
# |FaixaKm=5|Gamba=1|TipoPavimento=2|TipoChuva=1|0.9342105263157895|0.9874207870071718|
# |TipoChuva=1|Gamba=1|TipoPavimento=2|FaixaKm=5|0.9161290322580645|2.6516192720440723|
# |FaixaKm=5|TipoPavimento=4|Gamba=1|TipoChuva=1|0.9060773480662982|0.9576852143224176|
# |FaixaKm=5|Gamba=1|Vazamento=0|TipoChuva=1|0.9201680672268907|0.972578505086245|
# |FaixaKm=5|Vazamento=1|Gamba=1|TipoChuva=1|0.9038461538461539|0.9553269369419334|
# |FaixaKm=5|TipoChuva=1|Gamba=1|agua=0|0.888888888888889|1.1868042906294274|
# |agua=0|FaixaKm=5|Gamba=1|TipoChuva=1|0.9523809523809524|1.006626154427164|
# |FaixaKm=5|Gamba=1|arbustos=0|TipoChuva=1|0.9289617486338798|0.9818730522691188|
# |arbustos=1|FaixaKm=5|Gamba=1|TipoChuva=1|0.9004739336492892|0.9517626436408493|
# |FaixaKm=5|TipoChuva=1|Gamba=1|capimAlto=0|0.9194444444444444|1.122319363493385|
# |FaixaKm=5|capimAlto=0|Gamba=1|TipoChuva=1|0.9220055710306406|0.9745206684433447|
# |FaixaKm=5|TipoChuva=1|Gamba=1|floresta=1|0.8|1.5211413748378728|
# |FaixaKm=5|floresta=1|Gamba=1|TipoChuva=1|0.9320388349514563|0.9851254016141564|
# |FaixaKm=5|vegetacaoBaixa=0|Gamba=1|TipoChuva=1|0.917763157894737|0.9700366182218344|
# |TipoPavimento=2|TipoLocal=6|Gamba=1|FaixaKm=5|0.9210526315789473|2.6658700057151763|
# |FaixaKm=5|TipoLocal=6|Gamba=1|agua=0|0.8585526315789475|1.1463006902502157|
# |FaixaKm=5|TipoLocal=6|Gamba=1|capimAlto=0|0.9013157894736842|1.1001906306148383|
# |FaixaKm=5|Gamba=1|TipoPavimento=2|agua=0|0.861842105263158|1.1506926469178411|
# |agua=0|TipoPavimento=2|Gamba=1|FaixaKm=5|0.9225352112676057|2.670161144557374|
# |TipoPavimento=2|Gamba=1|arbustos=0|FaixaKm=5|0.898989898989899|2.6020122249144952|
# |FaixaKm=5|Gamba=1|TipoPavimento=2|capimAlto=0|0.9539473684210528|1.1644353389719095|
# |TipoPavimento=2|capimAlto=0|Gamba=1|FaixaKm=5|0.90625|2.623025666337611|
# |FaixaKm=5|Gamba=1|TipoPavimento=2|floresta=1|0.9210526315789473|1.7513140828725509|
# |TipoPavimento=2|floresta=1|Gamba=1|FaixaKm=5|0.9032258064516129|2.614272521733592|
# |FaixaKm=5|Gamba=1|TipoPavimento=2|vegetacaoBaixa=0|0.8026315789473685|1.3183841957835767|
# |TipoPavimento=2|vegetacaoBaixa=0|Gamba=1|FaixaKm=5|0.9172932330827068|2.654988903651033|
# |FaixaKm=5|TipoPavimento=4|Gamba=1|Vazamento=0|0.8453038674033149|1.3396923995819023|
# |FaixaKm=5|TipoPavimento=4|Gamba=1|agua=0|0.8232044198895028|1.0991053547887168|
# |FaixaKm=5|TipoPavimento=4|Gamba=1|capimAlto=0|0.8453038674033149|1.0318197082541711|
# |FaixaKm=5|Gamba=1|Vazamento=0|agua=0|0.8109243697478992|1.0827095865668672|
# |FaixaKm=5|Gamba=1|Vazamento=0|capimAlto=0|0.8697478991596638|1.0616573023880658|
# |FaixaKm=5|Vazamento=1|Gamba=1|agua=0|0.9166666666666666|1.2238919247115967|
# |FaixaKm=5|Vazamento=1|Gamba=1|capimAlto=0|0.9743589743589743|1.1893507547129527|
# |FaixaKm=5|Vazamento=1|Gamba=1|floresta=1|0.891025641025641|1.6942199607569255|
# |FaixaKm=5|Gamba=1|arbustos=0|agua=0|0.8852459016393442|1.1819403386186509|
# |arbustos=1|FaixaKm=5|Gamba=1|agua=0|0.8246445497630331|1.1010281511408073|
# |agua=0|FaixaKm=5|Gamba=1|capimAlto=0|0.9166666666666667|1.1189286705523176|
# |FaixaKm=5|capimAlto=0|Gamba=1|agua=0|0.8579387186629527|1.1454810214570934|
# |FaixaKm=5|floresta=1|Gamba=1|agua=0|0.8576051779935275|1.1450356930223236|
# |FaixaKm=5|vegetacaoBaixa=0|Gamba=1|agua=0|0.8585526315789475|1.1463006902502157|
# |FaixaKm=5|Gamba=1|arbustos=0|capimAlto=0|0.9234972677595629|1.127266440079533|
# |FaixaKm=5|Gamba=1|arbustos=0|floresta=1|0.8633879781420765|1.6416689701119118|
# |arbustos=1|FaixaKm=5|Gamba=1|capimAlto=0|0.9004739336492892|1.0991630197584161|
# |arbustos=1|floresta=1|Gamba=1|FaixaKm=5|0.8342541436464089|2.4146427928640386|
# |FaixaKm=5|capimAlto=0|Gamba=1|floresta=1|0.8217270194986072|1.5624537102269236|
# |FaixaKm=5|floresta=1|Gamba=1|capimAlto=0|0.9546925566343042|1.1653449525611073|
# |FaixaKm=5|vegetacaoBaixa=0|Gamba=1|capimAlto=0|0.9210526315789473|1.12428239624874|
# |FaixaKm=5|floresta=1|Gamba=1|vegetacaoBaixa=0|0.8220064724919094|1.3502089508942736|
# |FaixaKm=5|vegetacaoBaixa=0|Gamba=1|floresta=1|0.8355263157894737|1.5886920608915283|
